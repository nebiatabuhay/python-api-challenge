# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# !pip install citipy
# !pip install config
# Out:
# Requirement already satisfied: citipy in /Users/nebiatadugna/opt/anaconda3/envs/EnvBootcamp/lib/python3.6/site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in /Users/nebiatadugna/opt/anaconda3/envs/EnvBootcamp/lib/python3.6/site-packages (from citipy) (0.16)
# Requirement already satisfied: config in /Users/nebiatadugna/opt/anaconda3/envs/EnvBootcamp/lib/python3.6/site-packages (0.5.0.post0)

# %%
# !pip install openweathermapy
# Out:
# Requirement already satisfied: openweathermapy in /Users/nebiatadugna/opt/anaconda3/envs/EnvBootcamp/lib/python3.6/site-packages (0.6.6)

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import openweathermapy as owm
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# import API Key from config file
# from config import api_key

# # Create settings dictionary with information we're interested in
api_key='80138c754fd93462ceb556509673c138'
settings = {"units": "imperial", "appid": api_key}

# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") 
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={api_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: 
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')


WeatherPy_df.to_csv("weather.csv")
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | natal
# http://api.openweathermap.org/data/2.5/weather?q=natal&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 2 of Set 0 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 3 of Set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 4 of Set 0 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 5 of Set 0 | hamilton
# http://api.openweathermap.org/data/2.5/weather?q=hamilton&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 6 of Set 0 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 7 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 8 of Set 0 | pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?q=pyaozerskiy&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 9 of Set 0 | henties bay
# http://api.openweathermap.org/data/2.5/weather?q=henties%20bay&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 10 of Set 0 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?q=ciudad%20bolivar&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 11 of Set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 12 of Set 0 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 13 of Set 0 | yetholm
# http://api.openweathermap.org/data/2.5/weather?q=yetholm&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 14 of Set 0 | alta floresta
# http://api.openweathermap.org/data/2.5/weather?q=alta%20floresta&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 15 of Set 0 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 16 of Set 0 | kyabe
# http://api.openweathermap.org/data/2.5/weather?q=kyabe&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 17 of Set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 18 of Set 0 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 19 of Set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 20 of Set 0 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 21 of Set 0 | namtsy
# http://api.openweathermap.org/data/2.5/weather?q=namtsy&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 22 of Set 0 | vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 23 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 24 of Set 0 | shelburne
# http://api.openweathermap.org/data/2.5/weather?q=shelburne&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 25 of Set 0 | karaul
# http://api.openweathermap.org/data/2.5/weather?q=karaul&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 26 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 27 of Set 0 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial%20do%20cabo&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 28 of Set 0 | georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 29 of Set 0 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 30 of Set 0 | fairbanks
# http://api.openweathermap.org/data/2.5/weather?q=fairbanks&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 31 of Set 0 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 32 of Set 0 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 33 of Set 0 | cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 34 of Set 0 | urumqi
# http://api.openweathermap.org/data/2.5/weather?q=urumqi&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 35 of Set 0 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 36 of Set 0 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 37 of Set 0 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 38 of Set 0 | honningsvag
# http://api.openweathermap.org/data/2.5/weather?q=honningsvag&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 39 of Set 0 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 40 of Set 0 | dong hoi
# http://api.openweathermap.org/data/2.5/weather?q=dong%20hoi&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 41 of Set 0 | tilichiki
# http://api.openweathermap.org/data/2.5/weather?q=tilichiki&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 42 of Set 0 | ta khmau
# http://api.openweathermap.org/data/2.5/weather?q=ta%20khmau&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 43 of Set 0 | ixtapa
# http://api.openweathermap.org/data/2.5/weather?q=ixtapa&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 44 of Set 0 | shiraz
# http://api.openweathermap.org/data/2.5/weather?q=shiraz&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 45 of Set 0 | mehamn
# http://api.openweathermap.org/data/2.5/weather?q=mehamn&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 46 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 47 of Set 0 | nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 48 of Set 0 | diplo
# http://api.openweathermap.org/data/2.5/weather?q=diplo&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 49 of Set 0 | victoria
# http://api.openweathermap.org/data/2.5/weather?q=victoria&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# Processing Record 50 of Set 0 | cumaribo
# http://api.openweathermap.org/data/2.5/weather?q=cumaribo&units=imperial&APPID=80138c754fd93462ceb556509673c138
# HTTP Error 401: Unauthorized
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-236d845658f0> in <module>
#      30         count = 1
#      31         sets = sets+1
# ---> 32         time.sleep(60-(t1-t0))
#      33         t0=time.time()
#      34
#
# KeyboardInterrupt:

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df=pd.read_csv('weather.csv')

# %%
df.head()
# Out:
#               City  Cloudiness Country        Date  Max Temp  Wind Speed  \
# 0          Ushuaia           0      AR  1521583200     50.00       23.04
# 1  Bambous Virieux          75      MU  1521583200     78.80        5.70
# 2          Parfino          92      RU  1521585005     26.40        2.68
# 3        Boguchany           0      RU  1521585006     19.02        5.26
# 4          Mataura          92      NZ  1521585006     53.76        9.40
#
#      Lat     Lng  Humidity
# 0 -54.81  -68.31        66
# 1 -20.34   57.76        83
# 2  57.97   31.65        90
# 3  58.38   97.46        72
# 4 -46.19  168.86       100

# %%
df.describe()
# Out:
#        Cloudiness          Date    Max Temp  Wind Speed         Lat  \
# count  543.000000  5.430000e+02  543.000000  543.000000  543.000000
# mean    38.344383  1.521584e+09   50.909448    7.939558   21.813941
# std     34.772550  1.336836e+03   27.234950    5.480308   33.000806
# min      0.000000  1.521580e+09  -33.680000    0.670000  -54.810000
# 25%      0.000000  1.521583e+09   31.990000    3.415000   -4.585000
# 50%     32.000000  1.521585e+09   55.400000    6.600000   27.270000
# 75%     75.000000  1.521585e+09   75.430000   11.355000   49.925000
# max    100.000000  1.521586e+09   98.600000   37.020000   78.220000
#
#               Lng    Humidity
# count  543.000000  543.000000
# mean    14.409816   75.465930
# std     89.366223   20.542419
# min   -179.170000    8.000000
# 25%    -65.915000   64.500000
# 50%     19.700000   79.000000
# 75%     91.850000   93.000000
# max    179.320000  100.000000

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
import seaborn as sns
from datetime import datetime
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(df["Lat"], df["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(df["Lat"], df["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(df["Lat"], df["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(df["Lat"],df["Wind Speed"], color='orange', alpha=0.5)

plt.ylim((df["Wind Speed"].min()-5),(df["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_df = df.loc[pd.to_numeric(df["Lat"]).astype(float) > 0, :]
southern_df = df.loc[pd.to_numeric(df["Lat"]).astype(float) < 0, :]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a negative correlation.")
print("In the nothern hemisphere, as you move away from the equator the temperature decreases.")
plt.show()
# Out:
# Regression line equation is: y = -1.22x + 90.75
# The r-squared is: -0.8860884916407807
# The regression displays a negative correlation.
# In the nothern hemisphere, as you move away from the equator the temperature decreases.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Max Temp']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
print("The regression displays a positive correlation.")
print("In the southern hemisphere, as you get closer to the equator the temperature increases.")
plt.show()
# Out:
# Regression line equation is: y = 0.52x + 81.26
# The r-squared is: 0.6877838683208343
# The regression displays a positive correlation.
# In the southern hemisphere, as you get closer to the equator the temperature increases.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = -0.0x + 72.96
# The r-squared is: -0.002525656996935503

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Humidity']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.48x + 91.41
# The r-squared is: 0.37966463077915685

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.19x + 30.37
# The r-squared is: 0.10876226675960339

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Cloudiness']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.33x + 46.05
# The r-squared is: 0.14235849892029928

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(northern_df['Lat']).astype(float)
y_values = pd.to_numeric(northern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = 0.02x + 7.12
# The r-squared is: 0.08335945861620789

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = pd.to_numeric(southern_df['Lat']).astype(float)
y_values = pd.to_numeric(southern_df['Wind Speed']).astype(float)
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
print(f"Regression line equation is: {line_eq}")
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# Regression line equation is: y = -0.11x + 5.39
# The r-squared is: -0.3232479112467031
